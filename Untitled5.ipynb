# %% [markdown]
# <a href="https://colab.research.google.com/github/benjohn94/Healthcare-App/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
shopping_cart= []                         # this is how we create an Empty List

# %%
print('Total Products in CART '            ,               len(  shopping_cart)     )
# Out:
# Total Products in CART  0

# %%
shopping_cart.append('iPhone')

# %%
shopping_cart
# Out:
# ['iPhone']

# %%
shopping_cart.append('iPhone')
shopping_cart.append('Samsung')
shopping_cart.append('Nokia')
shopping_cart.append('Vivo')

# %%
shopping_cart
# Out:
# ['iPhone', 'BMW', 'iPhone', 'Samsung', 'Nokia', 'Vivo']

# %%
shopping_cart.remove('iPhone')

# %%
shopping_cart
# Out:
# ['BMW', 'Samsung', 'Nokia', 'Vivo']

# %%
shopping_cart[-1]
# Out:
# 'Vivo'

# %%
shopping_cart[3]
# Out:
# 'Vivo'

# %%
shopping_cart[0]
# Out:
# 'BMW'

# %%
shopping_cart[-4]
# Out:
# 'BMW'

# %%
shopping_cart
# Out:
# ['BMW', 'Samsung', 'Nokia', 'Vivo']

# %%
for product in shopping_cart:
  print(product)
# Out:
# BMW
# Samsung
# Nokia
# Vivo

# %%
for product in shopping_cart:
  print(product[0])
# Out:
# B
# S
# N
# V

# %%
for product in shopping_cart:
  print(product[-1])
# Out:
# W
# g
# a
# o

# %%
weight_in_pounds = [ 105 , 95 , 85 , 150 , 195 ]

# %%
for weight in weight_in_pounds :
  print( weight * 0.45 )
# Out:
# 47.25
# 42.75
# 38.25
# 67.5
# 87.75

# %%
weight_in_kg= []
for weight in weight_in_pounds :
  weight_in_kg.append ( weight * 0.45 )

# %%
logs = [ 2700, 1900, 1300 , 700 , 1500 ]

# %%
results = []

for ms in logs :
  results.append(ms/1000)

# %%
print(results)
# Out:
# [2.7, 1.9, 1.3, 0.7, 1.5]

# %%
msg='Crocodile'

# %%
msg.upper()
# Out:
# 'CROCODILE'

# %%
msg.lower()
# Out:
# 'crocodile'

# %%
msg.index('r')
# Out:
# 1

# %%
luckyNumber="777"

# %%
luckyNumber.isdigit()
# Out:
# True

# %%
luckyNumber="77 7"

# %%
luckyNumber.isdigit()
# Out:
# False

# %%
price="12"

# %%
price.isdigit()
# Out:
# True

# %%
int(price)
# Out:
# 12

# %%
msg='crocodile'

# %%
msg[1:5]
# Out:
# 'roco'

# %%
msg[3:7]
# Out:
# 'codi'

# %%
msg[2:5]
# Out:
# 'oco'

# %%
msg[:5]
# Out:
# 'croco'

# %%
msg[5:]
# Out:
# 'dile'

# %%
msg[:]
# Out:
# 'crocodile'

# %%
value='01234'

# %%
value[0:3]
# Out:
# '012'

# %%
value[0:]
# Out:
# '01234'

# %%
msg='crocodile'

# %%
msg[1:7:2]
# Out:
# 'rcd'

# %%
msg[0:8:3]
# Out:
# 'cci'

# %%
msg[0:8:2]
# Out:
# 'cooi'

# %%
msg[0:8:1]
# Out:
# 'crocodil'

# %%
msg='classroom'

# %%
msg[::2]
# Out:
# 'casom'

# %%
encrypt='AXWYEMSTOPMQE'

# %%
encrypt[::2]
# Out:
# 'AWESOME'

# %%
encrypt[::-1]
# Out:
# 'EQMPOTSMEYWXA'

# %%
msg='One Day I will make Onions CRY'

# %%
msg.split()
# Out:
# ['One', 'Day', 'I', 'will', 'make', 'Onions', 'CRY']

# %%
heroes = 'spiderman,ironman,hulk,thanos,antman,flash'

# %%
result=heroes.split(',')

# %%
result
# Out:
# ['spiderman', 'ironman', 'hulk', 'thanos', 'antman', 'flash']

# %%
result.remove('thanos')

# %%
result
# Out:
# ['spiderman', 'ironman', 'hulk', 'antman', 'flash']

# %%
del result[-1]

# %%
result
# Out:
# ['spiderman', 'ironman', 'hulk', 'antman']

# %%
' '.join(result)
# Out:
# 'spiderman ironman hulk antman'

# %%
scores= "english 45 maths 30 science 50"

# %%
s_list=scores .split()

# %%
s_list
# Out:
# ['english', '45', 'maths', '30', 'science', '50']

# %%
for item in s_list:
  print(item , item.isdigit())
# Out:
# english False
# 45 True
# maths False
# 30 True
# science False
# 50 True

# %%
for item in s_list:
  if item.isdigit():
    print(item)
# Out:
# 45
# 30
# 50

# %%
marks = []
for item in s_list:
  if item.isdigit()==True:
    marks.append( int(item) )

# %%
marks
# Out:
# [45, 30, 50]

# %%
print('sum' , sum(marks))
# Out:
# sum 125
